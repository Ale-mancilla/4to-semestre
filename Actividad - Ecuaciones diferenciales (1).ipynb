# %% [markdown]
# # Actividad - Ecuaciones diferenciales

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1. Resolver numéricamente con `solve_ivp` la siguiente ecuación diferencial:
# $$\frac{dx}{dt}=\frac{x}{t+1}$$

# %% [markdown]
# Grafique con condición inicial $x_0 = 2$

# %%
from scipy.integrate import solve_ivp, odeint

# %%
def funcion(x, t) :
    return x/(t+1)

# %%
t = np.linspace(0, 50, 100)
x0 = 2

x = odeint(funcion, x0, t)
x = x[:, 0]

plt.figure()
plt.plot(t, x, label="Solución numérica")
plt.legend(loc="best")
plt.grid()

# %% [markdown]
# 2. Encuentre la solución numérica para un oscilador armónico simple:
#
# $$
# \frac{d^2 x}{dt^2} +  \omega_{0}^2 x = 0.
# $$
# Donde $x_0=0.5$, $\dot{x}_0=0.1$ y $\omega_0=3$.

# %% [markdown]
# 2.1 Defina una función, cuyos argumentos de entrada sean:
#
#
# 1. el tiempo $t$,
# 2. el arreglo $[x,\dot{x}]$.
#
# Y la salida:
#
# 1. el arreglo $[\dot{x},\ddot{x}]$.
#
#   Considerando el argumento de la frecuencia natural $\omega_0$ debe ser una variable global.

# %%
def posicion(t=0, w0=3, x0=0.5, v0=00.1) :
    A = x0
    B = v0/w0
    return A*np.cos(w0*3*t) + B*np.sin(w0*3*t)
def velocidad(t,w0):
    A= 0.5
    B= 0.1
    return A*np.cos(w0*t) + B*np.sin(w0*t)

# %% [markdown]
# Grafique

# %%
t=np.linspace(0,10,100)
w0=3
plt.figure()
plt.plot(t,posicion(t,w0), label="Posicion")
plt.plot(t,velocidad(t,w0), label="Velocidad")
plt.legend(loc="best")
plt.grid()



from ipywidgets import*

def grafico(t=0, a=1,x0=0.5, v0=0.1):
    w0= 3
    C= posicion(t,a, x0=x0, v0=v0)
    x = a*np.cos(3*t)
    y = -a*np.cos(C)
    
    fig =plt.figure()
    ax= fig.add_subplot(111)
    ax.plot([-1.1, 1.1],[0,0], "k")
    ax.plot(0,0, "xr", ms=20)
    ax.plot(x,y, "ob", ms=20)
    ax.plot([0,x], [0,y], "b", lw=4)
    
    plt.xlim([-1.1, 1.1])
    plt.ylim([-1.1, 0.1])

interact(grafico, t=(0, 10, 0.1), l=fixed(1))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=10.0), IntSlider(value=1, description='a', m…
# <function __main__.grafico(t=0, a=1, x0=0.5, v0=0.1)>

# %% [markdown]
# Asigne a los parámetros de la solución analítica $C_1=x_0$ y $C_2=\frac{\dot{x}_0}{\omega_0}$.

# %%
def posicion(t, w0, x0=0.5, v0=0.1) :
    A = x0
    B = v0/w0
    return A*np.cos(w0*3*t) + B*np.sin(w0*3*t)
def velocidad(t,w0):
    A= 0.5
    B= 0.1
    return A*np.cos(w0*t) + B*np.sin(w0*t)

# %%
w0= 3
x0=0.5
v0= 0.1
x=posicion(t,w0,x0,v0)
v=velocidad(t,w0,x0,v0)
plt.figure(figsize=(4,4))
plt.plot(x, v)
plt.xlabel("Posición")
plt.ylabel("velocidad")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1120/2245459606.py in <module>
#       3 v0= 0.1
#       4 x=posicion(t,w0,x0,v0)
# ----> 5 v=velocidad(t,w0,x0,v0)
#       6 plt.figure(figsize=(4,4))
#       7 plt.plot(x, v)
#
# TypeError: velocidad() takes 2 positional arguments but 4 were given

# %% [markdown]
# Redefina la función para graficarla (con la palabra reservada ***def***) en un intervalo de tiempo de 0 a 2 segundos. Comparela en un mismo grafico con la solución numérica obtenida.
